# %% [markdown]
# # Show Image By Using OpenCv

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import cv2 as cv 
import os 
#Read Image 
os.chdir(R"D:\\AI\\AI Models\\3. OpenCV\\0- OpenCV\\Data\\Images")
img = cv.imread('lena.jpg',-1)
print(cv.imshow('Lena',img))
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# None

# %% [markdown]
# # Show Image By Using matplotlib

# %%
plt.imshow(img)

# %% [markdown]
# # Convert Image form BGR2RGB

# %%
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
os.chdir(R"D:\\AI\\AI Models\\3. OpenCV\\0- OpenCV\\Data\\Images")
img = cv.imread('gradient.png',0)
#Apply Many Types Of Thresholds
_,th1 = cv.threshold(img,55,255,cv.THRESH_BINARY)
ret2,th2 = cv.threshold(img,200,255,cv.THRESH_BINARY_INV)
ret3,th3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
_,th4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
_,th5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img ,th1,th2,th3,th4,th5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.yticks([]),plt.xticks([])

# %%
os.chdir(R"D:\\AI\\AI Models\\3. OpenCV\\0- OpenCV\\Data\\Images")
img = cv.imread('gradient.png',0)#Apply Many Types Of Thresholds
_,th1 = cv.threshold(img,55,255,cv.THRESH_BINARY)
ret2,th2 = cv.threshold(img,200,255,cv.THRESH_BINARY_INV)
ret3,th3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
_,th4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
_,th5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img ,th1,th2,th3,th4,th5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.yticks([]),plt.xticks([])
