# %%
import cv2 as cv  
import dlib 
import numpy as np 
import matplotlib.pyplot as plt 
#import os  
#os.chdir(R"D:\\AI\\AI Models\\3. OpenCV") 
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
cap = cv.VideoCapture(0)# zero for the first web cam
while True:
    _,frame = cap.read()
    gray = cv.cvtColor(frame,cv.COLOR_BGR2GRAY)
    faces = detector (gray)
    for face in faces:
        print(face)
        x1 = face.left()
        y1 = face.top()
        x2 = face.right()
        y2 = face.bottom()
        #cv.rectangle(frame,(x1,y1),(x2,y2),(0,255,0),3)
        landmarks = predictor(gray,face)
        for n in range (0,68):
            x = landmarks.part(n).x 
            y = landmarks.part(n).y 
            #print(x,y) 
            cv.circle(frame,(x,y),3,(0,255,0),-1)
    cv.imshow('Frame',frame)
    if cv.waitKey(1) == ord('q'):
        cv.destroyAllWindows()
        break 
cap.release()
cv.destroyAllWindows()
# Out:
# [(360, 161) (510, 311)]
# [(360, 161) (510, 311)]
# [(360, 161) (510, 311)]
# [(353, 154) (532, 333)]
# [(353, 154) (532, 333)]
# [(373, 174) (552, 353)]
# [(373, 174) (552, 353)]
# [(373, 174) (552, 353)]
# [(373, 194) (552, 373)]
# [(373, 214) (552, 393)]
# [(373, 214) (552, 393)]
# [(394, 261) (543, 410)]
# [(394, 261) (543, 410)]
# [(373, 254) (552, 433)]
# [(373, 254) (552, 433)]
# [(393, 234) (572, 413)]
# [(393, 234) (572, 413)]
# [(433, 74) (612, 254)]
# [(353, 214) (532, 393)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(294, 194) (443, 344)]
# [(300, 203) (424, 328)]
# [(277, 194) (427, 344)]
# [(277, 194) (427, 344)]
# [(286, 203) (411, 328)]
# [(286, 189) (411, 314)]
# [(286, 189) (411, 314)]
# [(261, 178) (410, 327)]
# [(272, 176) (397, 300)]
# [(272, 176) (397, 300)]
# [(286, 176) (411, 300)]
# [(286, 176) (411, 300)]
# [(277, 178) (427, 327)]
# [(277, 178) (427, 327)]
# [(277, 178) (427, 327)]
# [(294, 178) (443, 327)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(313, 194) (492, 373)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(313, 194) (492, 373)]
# [(327, 211) (476, 360)]
# [(327, 211) (476, 360)]
# [(313, 194) (492, 373)]
# [(313, 194) (492, 373)]
# [(313, 194) (492, 373)]
# [(327, 194) (476, 344)]
# [(327, 194) (476, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(344, 194) (493, 344)]
# [(313, 194) (492, 373)]
# [(327, 194) (476, 344)]
# [(313, 194) (492, 373)]
# [(313, 194) (492, 373)]
# [(313, 194) (492, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(311, 211) (460, 360)]
# [(293, 194) (473, 373)]
# [(293, 194) (473, 373)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
# [(311, 194) (460, 344)]
