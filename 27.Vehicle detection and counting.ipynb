# %%
import numpy as np 
import cv2 as cv  
import os 
from time import sleep
largura_min = 80
altura_min = 80
os.chdir(R"D:\\AI\\AI Models\\3. OpenCV\\0- OpenCV\\Data\\Videos")
ww = 80 
hh = 80
offset = 6
y1 = 550 
#FPS To video
delay = 60
detec = []
carros = 0
#----------------------------------------------------------
#Create Function To calaculate circle Center 
def pega_center(x,y,w,h):
    x1 = int (w/2)
    y1 = int (h/2)
    cx = x + x1 
    cy = y + y1 
    return cx , cy 
#********************************************************
#1. Read Video 
cap = cv.VideoCapture('video.mp4')
#cap = cv.resize(cap,(450,500))
#create algorithm MOg(1) To make object detection and 
BGS = cv.createBackgroundSubtractorMOG2()
while True : 
    ret,frame1 = cap.read()
    print('The frame Shape are --> ', frame1.shape)
    tempo = float(1/delay)
    sleep(tempo)
    gray = cv.cvtColor(frame1,cv.COLOR_BGR2GRAY)
    blur = cv.GaussianBlur(gray,(3,3),5)
    img_sub= BGS.apply(blur)
    dilat = cv.dilate(img_sub,np.ones((5,5)))
    #Applying some morphologiacal Processing 
    kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))          
    dilatada = cv.morphologyEx(dilat, cv. MORPH_CLOSE, kernel)          
    dilatada = cv.morphologyEx(dilatada, cv. MORPH_CLOSE, kernel)          
    #--------------------------------------------------------------------
    #Find Contours 
    contour, h  = cv.findContours(dilat,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
    #Draw line because when any car is paases from line line color change it's closet from counter 
    cv.line(frame1,(25,y1),(1200,y1),(176,130,39),2)
    for (i,c) in enumerate(contour):
        (x,y,w,h)= cv.boundingRect(c)
        validar_contourNO = (w>=ww) and (h >=hh)
        if not validar_contourNO: continue
        cv.rectangle(frame1,(x,y),(x+w,y+h),(0,255,0),2)
        center = pega_center(x,y,w,h)
        detec.append(center)
        cv.circle(frame1,center,4,(0,0,255),-1)
        #--------------------------------------------
        #Create for loop --> because makes counting to objects 
        for (x,y) in detec:
            if (y<(y1 + offset)) and (y1>(y1-offset)):
                carros+=1
                cv.line(frame1,(25,y1),(1200,y1),(0, 127, 255),3)
                detec.remove((x,y))
                print('The Number of cars detected are --> '+str(carros))
    cv.putText(frame1, "VEHICLE COUNT : "+str(carros), (320, 70),cv.FONT_HERSHEY_COMPLEX, 2, (0, 0, 255), 4)
    frame1 = cv.resize(frame1,(450,500))
    dilatada= cv.resize(dilatada,(450,500))
    cv.imshow("Video Original", frame1)
    cv.imshow(" Detectar ", dilatada)
    if cv.waitKey(1) == 27:break       
cv.destroyAllWindows()
cap.release()
# Out:
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 1
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 2
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 3
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 4
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 5
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 6
# The Number of cars detected are --> 7
# The frame Shape are -->  (720, 1280, 3)
# The Number of cars detected are --> 8
# The frame Shape are -->  (720, 1280, 3)
# ...

# %%
import cv2
import os 
import numpy as np
from time import sleep
largura_min = 80
altura_min = 80
offset = 6
pos_linha = 550
# FPS to vídeo
delay = 60
detec = []
carros = 0
def pega_centro(x, y, w, h):
    x1 = int(w / 2)
    y1 = int(h / 2)
    cx = x + x1
    cy = y + y1
    return cx, cy
# video source input
os.chdir(R"D:\\AI\\AI Models\\3. OpenCV\\0- OpenCV\\Data\\Videos")
cap = cv2.VideoCapture('video.mp4')
subtracao = cv2.createBackgroundSubtractorMOG2()
while True:
    ret, frame1 = cap.read()        
    tempo = float(1/delay)         
    sleep(tempo)         
    grey = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)         
    blur = cv2.GaussianBlur(grey, (3, 3), 5)          
    img_sub = subtracao.apply(blur)          
    dilat = cv2.dilate(img_sub, np.ones((5, 5)))           
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))           
    dilatada = cv2.morphologyEx(dilat, cv2. MORPH_CLOSE, kernel)          
    dilatada = cv2.morphologyEx(dilatada, cv2. MORPH_CLOSE, kernel)          
    contorno, h = cv2.findContours(dilatada, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)          
    cv2.line(frame1, (25, pos_linha), (1200, pos_linha), (176, 130, 39), 2)            
    for(i, c) in enumerate(contorno):            
        (x, y, w, h) = cv2.boundingRect(c)                
        validar_contorno = (w >= largura_min) and (h >= altura_min)                 
        if not validar_contorno:                 
            continue                      
        cv2.rectangle(frame1, (x, y), (x+w, y+h), (0, 255, 0), 2)                    
        centro = pega_centro(x, y, w, h)                    
        detec.append(centro)                     
        cv2.circle(frame1, centro, 4, (0, 0, 255), -1)                    
        for (x, y) in detec:                 
            if (y < (pos_linha + offset)) and (y > (pos_linha-offset)):                         
                carros += 1                          
                cv2.line(frame1, (25, pos_linha), (1200, pos_linha), (0, 127, 255), 3)                         
                detec.remove((x, y))                        
                print("No. of cars detected : " + str(carros))                        
    cv2.putText(frame1, "VEHICLE COUNT : "+str(carros), (320, 70),cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 255), 4)
    frame1 = cv.resize(frame1,(450,500))
    dilatada= cv.resize(dilatada,(450,500))
    cv2.imshow("Video Original", frame1)
    cv2.imshow(" Detectar ", dilatada)
    if cv2.waitKey(1) == 27:
        break        
cv2.destroyAllWindows()
cap.release()
# Out:
# No. of cars detected : 1
# No. of cars detected : 2
# No. of cars detected : 3
# No. of cars detected : 4
# No. of cars detected : 5
# No. of cars detected : 6
# No. of cars detected : 7
# No. of cars detected : 8
# No. of cars detected : 9
